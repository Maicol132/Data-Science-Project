# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Pregunta 1: Extracción de datos de acciones de Tesla usando yfinance

# %%
import yfinance as yf

# Extraer datos de Tesla
tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")

# Mostrar las primeras filas
tesla_data.reset_index(inplace=True)
tesla_data.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %% [markdown]
# Pregunta 2: Extracción de ingresos de Tesla con Web Scraping

# %%
pip install requests beautifulsoup4 pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Pregunta 2: Extracción de ingresos de Tesla con Web Scraping

# %%
# !pip install lxml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 137.6 MB/s eta 0:00:00
# ...

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# PREGUNTA 1

# %%
import yfinance as yf

tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")
print(tesla_data.head())  # Muestra las primeras filas
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers)

# %% [markdown]
# PREGUNTA 2

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# Extrae los datos de ingresos
tables = soup.find_all("table")
for table in tables:
    print(table.text)  # Muestra la información extraída

# %% [markdown]
# PREGUNTA 3

# %%
gamestop = yf.Ticker("GME")
gamestop_data = gamestop.history(period="max")
print(gamestop_data.head())  # Muestra las primeras filas
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2002-02-13 00:00:00-05:00  1.620128  1.693350  1.603296  1.691667  76216000
# 2002-02-14 00:00:00-05:00  1.712707  1.716073  1.670626  1.683250  11021600
# 2002-02-15 00:00:00-05:00  1.683250  1.687458  1.658002  1.674834   8389600
# 2002-02-19 00:00:00-05:00  1.666418  1.666418  1.578047  1.607504   7410400
# 2002-02-20 00:00:00-05:00  1.615921  1.662210  1.603296  1.662210   6892800
#
#                            Dividends  Stock Splits
# Date
# 2002-02-13 00:00:00-05:00        0.0           0.0
# 2002-02-14 00:00:00-05:00        0.0           0.0
# 2002-02-15 00:00:00-05:00        0.0           0.0
# 2002-02-19 00:00:00-05:00        0.0           0.0
# 2002-02-20 00:00:00-05:00        0.0           0.0

# %% [markdown]
# PREGUNTA 4

# %%
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# Extrae los datos de ingresos
tables = soup.find_all("table")
for table in tables:
    print(table.text)  # Muestra la información extraída

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 104.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 123.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 72.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 141.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# PREGUNTA 5

# %%
import matplotlib.pyplot as plt

tesla_data["Close"].plot(title="Precio de Acciones de Tesla", figsize=(10, 5))
plt.xlabel("Fecha")
plt.ylabel("Precio de Cierre")
plt.show()

# %% [markdown]
# PREGUNTA 6

# %%
gamestop_data["Close"].plot(title="Precio de Acciones de GameStop", figsize=(10, 5))
plt.xlabel("Fecha")
plt.ylabel("Precio de Cierre")
plt.show()
